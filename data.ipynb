# %%
import pandas as pd

# Import CSV file
df = pd.read_csv("shipments_2000.csv")

# Print DataFrame
df.head(10)
# Out:
#   Shipment_ID Origin_Region Destination_Region Shipment_Date  \
# 0    SHP00001          East            Central    2026-04-02
# 1    SHP00002       Central               West    2026-05-13
# 2    SHP00003         North              South    2026-02-08
# 3    SHP00004         North               West    2026-04-15
# 4    SHP00005         North              South    2026-04-16
# 5    SHP00006          East               East    2026-03-26
# 6    SHP00007         South              South    2026-01-25
# 7    SHP00008         North               West    2026-05-19
# 8    SHP00009         North               East    2026-06-06
# 9    SHP00010          East               West    2026-01-17
#
#   Expected_Delivery_Date Actual_Delivery_Date Shipment_Status Carrier
# 0             2026-04-09           2026-04-08       Delivered     UPS
# 1             2026-05-19           2026-05-19       Delivered     UPS
# 2             2026-02-15                  NaN      In Transit   FedEx
# ...

# %%
print(df[["Origin_Region", "Destination_Region", "Shipment_Status", "Carrier"]].nunique())
# Out:
# Origin_Region         5
# Destination_Region    5
# Shipment_Status       5
# Carrier               3
# dtype: int64

# %%
df["Origin_Region"].value_counts()
# Out:
# Origin_Region
# East       420
# West       399
# South      396
# Central    394
# North      390
# Name: count, dtype: int64

# %%
df["Destination_Region"].value_counts()
# Out:
# Destination_Region
# Central    423
# East       415
# North      395
# West       393
# South      374
# Name: count, dtype: int64

# %%
df[ "Shipment_Status"].value_counts()
# Out:
# Shipment_Status
# Delivered     1409
# In Transit     272
# Delayed        218
# Cancelled      100
# Completed        1
# Name: count, dtype: int64

# %%
df["Carrier"].value_counts()
# Out:
# Carrier
# UPS      691
# FedEx    672
# DHL      637
# Name: count, dtype: int64
